# %% [markdown]
# <h1 align='center'> 신호및시스템 중간고사</h1>
#
# <h3 align='center'> 담당교수 : 박섭형</h3>
#
# <p style="text-align: right"> 2021.4.22</p>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# - 파일 이름에서 00000000을 자신의 학번으로, name을 자신의 이름으로 수정하세요.
#
# - 다음 줄에 자신의 이름, 학번, 학과(전공)을 적으세요.
#
# * 이름: 장윤제  &nbsp;&nbsp;          학번: 20175334   &nbsp;&nbsp;         학과(전공): 스마트 IoT
#
# </div>
#
# - 주의 사항
#   - 시험 시간 동안에는 카메라를 켜고 있어야 함
#   - 시험 시간: 오전 11:00 ~ 오후 12:00 (1시간)
#   - 11:55부터 12:55 사이에 ipynb 파일을 upload 해야 함
#   - 오후 12:00부터 동영상 녹화 시작
#   - SmartLead에 문제 풀이 설명 동영상 녹화 파일 upload 마감 시간: 오후 12:30
#   - 녹화를 시작하면 마스크를 착용한 학생들은 마스크를 살짝 내려서 얼굴을 확인하고 녹화 시작
#   - 학번 이름을 말한 후에 설명 시작
#   - 한 문제당 설명 시간이 3분을 넘지 말아야 함 (전체 9분 이내로 녹화)

# %% [markdown]
# **채점**
#
# |문제 | 문제 1 | 문제 2-1 | 문제 2-2 | 문제 3-1 | 문제 3-2 | 합계 |
# --|--|--|--|--|--|--
# 만점 | 20 | 15 | 10 | 15 | 10 | 70
# 점수 |  |  |  |  |  |

# %% [markdown]
# ### 문제 1.
#
# signed 6-bit 데이터를 사용한 연산에서 다음 물음에 답하라.
#
# 1) signed 6-bit 데이터형이 표현할 수 있는 정수의 최댓값과 최솟값을 적어라.
#
#   - 최댓값: $2^{6-1}-1 = 31$
#   - 최솟값: $-2^{6-1} = -32$
#
# 2) 다음 연산 결과를 적어라
#
#   - $ 28 + 9 = -27$
#   - $ -15 - 20 = 29$

# %% [markdown]
# ### 문제 2.
#
# #### 문제 2-1.
#
# 구간 $[-4, 4]$에서 다음과 같이 정의되는 함수의 그래프를 그려라. 시변수 $t$와 $x(t)$를 샘플링한 값들을 numpy의 다차원 배열(ndarray)을 이용하여 저장하고, 그래프를 그릴 때 샘플링 주파수는 50 Hz로 설정한다. 시변수 $t$의 구간을 나타내는 숫자의 단위는 초(s)이다.
#
# $$ x(t) = \left\{ \begin{array}{ll}
# t + 4 & -4 \le t < -1 \\
# 3 & -1 \le t < 0 \\
# \frac{3}{4}(t-2)^2 & 0 \le t \le 4 \\
#  \end{array} \right.
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

Ts = 0.02    #f = 1/50

time = np.arange(-4,4+Ts,Ts)    #-4~4 구간을 Ts만큼 쪼갠것

def x(t):
    if t<-1:
        val = t+4
    elif t<0:
        val = 3
    else:
        val = (3/4)*((t-2)**2)
    return val

x = np.array([x(t) for t in time])


plt.plot(t,x)
plt.xlabel("time(sec)", loc='right')
plt.show()

# %% [markdown]
# #### 문제 2-2.
#
# 문제 2-1에 주어진 $x(t)$를 다음과 같이 우함수 성분과 기함수 성분의 합으로 표현할 수 있다.
#
# $$x(t) = x_e(t) + x_o(t),$$
#
# 여기에서 $x_e(t) = \frac{1}{2}(x(t) + x(-t))$과 $x_o(t) = \frac{1}{2}(x(t) - x(-t))$이다.
#
# $x_e(t)$, $x_o(t)$, $x_e(t)+x_o(t)$의 그래프를 다음과 같이 그리는 프로그램을 작성하라.
#
# (아래 그래프는 $x_e(t)$와 $x_o(t)$의 수식을 구한 후에 그래프를 그리는 것이 아니라 이미  만들어 둔 numpy ndarray x를 이용해서 ndarray x_e와 x_o를 만든 다음에 그래프를 그리는 문제임.)
#
# 참고로 다음 그래프가 그려져야 한다.
#
# <img src='x-even-odd.png' width ='50%'></img>

# %%
x1 = np.array([(x(t)+x(-t))/2 for t in time])
x2 = np.array([(x(t)-x(-t))/2 for t in time])
x3 = x1+x2

plt.plot(t,x1)
plt.xlabel("time(sec)", loc='right')
plt.ylabel("$x_e(t)$")
plt.show()

plt.plot(t,x2)
plt.xlabel("time(sec)", loc='right')
plt.ylabel("$x_0(t)$")
plt.show()

plt.plot(t,x3)
plt.xlabel("time(sec)", loc='right')
plt.ylabel("$x_e(t)+x_0(t)$")
plt.show()

# %% [markdown]
# ### 문제 3.
#
# 다음과 같이 주어지는 방정식을 생각해 보자.
#
# $$z^4 = j.$$

# %% [markdown]
# #### 문제 3-1.
#
# SymPy를 이용해서 이 방정식의 해를 구하고, Markdown cell 안에 직접 이 해를 표시하는 수식을 작성하라.

# %%
# SymPy를 이용해서 방정식의 해를 구하는 프로그램을 이 셀에 작성하라
import math
from sympy import *
import IPython.display as disp


z = Symbol('z')

z = solve(z**4-I,z)
for z in z:
    disp.display(z)
# Out:
# -sqrt(1/2 - sqrt(2)/4) + I*sqrt(sqrt(2)/4 + 1/2)
# sqrt(1/2 - sqrt(2)/4) - I*sqrt(sqrt(2)/4 + 1/2)
# -sqrt(sqrt(2)/4 + 1/2) - I*sqrt(1/2 - sqrt(2)/4)
# sqrt(sqrt(2)/4 + 1/2) + I*sqrt(1/2 - sqrt(2)/4)

# %% [markdown]
# **답**: 이 방정식의 해는 다음과 같다.
#
# $$z_1 = -\sqrt{\frac{1}{2} - \frac{\sqrt{2}}{4}} + j\sqrt{\frac{\sqrt{2}}{4} + \frac{1}{2}}$$
# $$z_2 = \sqrt{\frac{1}{2} - \frac{\sqrt{2}}{4}} - j\sqrt{\frac{\sqrt{2}}{4} + \frac{1}{2}}$$
# $$z_3 = -\sqrt{\frac{\sqrt{2}}{4} + \frac{1}{2}} - j\sqrt{\frac{1}{2} - \frac{\sqrt{2}}{4}}$$
# $$z_4 = \sqrt{\frac{\sqrt{2}}{4} + \frac{1}{2}} + j\sqrt{\frac{1}{2} - \frac{\sqrt{2}}{4}}$$

# %% [markdown]
# #### 문제 3-2.
#
# 문제 3-1에서 구한 해를 복소 평면에서 점으로 그리는 Python 프로그램을 작성하라.
#
# 참고로 다음과 같은 그림을 그려야 한다. 두 축에 label도 작성해야 한다.
#
# <img src='z-solutions.png' width='60%'></img>

# %%
type(z[0])
# Out:
# sympy.core.add.Add

# %%
for n in range(len(z)):
    
    z[n] = complex(z[n])

real = [n.real for n in z]
imag = [(n).imag for n in z]


a = plt.axes(xlim=(-1,1),ylim=(-1,1))
a.set_aspect('equal')


plt.scatter(real,imag)

plt.xlabel("$\Re e$")
plt.ylabel("$\Im m$")
# Out:
# Text(0, 0.5, '$\\Im m$')

# %% [markdown]
# ### 문제 4. (30 점)
#
# 정현파를 이용해서 악보 연주하는 프로그램을 완성하고 각자 1분 길이 이상의 곡을 선택해서 악보를 표현하고 연주하는 프로그램을 만들어서 별도로 제출하라.
#
# - 마감일시: 5월 1일 18:00
# - 악보의 난이도에 따라서 최대 20 점의 추가 점수 있음.
